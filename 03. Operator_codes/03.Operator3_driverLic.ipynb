# %% [markdown]
# # Operator 활용 실습 #
#  - 개요: 운전면허 점수를 입력받아 합격인지 불합격인지 판별하는 프로그램
#  - 입력: 운전면허 필기 점수
#  - 출력: 합격/불합격
#  - 조건: 70점 이상이 합격

# %%
score = int(input("운전면허 필기 점수를 입력하세요: "))
# Out:
# 운전면허 필기 점수를 입력하세요: 69

# %%
score
# Out:
# 69

# %%
print(score >= 70)
# Out:
# False

# %%
#print("안녕 파이썬"); print("두번째"); num1 = 30

# %%
'''
print("안녕 파이썬") 
print("두번째") 
num1 = 30
'''
# Out:
# '\nprint("안녕 파이썬") \nprint("두번째") \nnum1 = 30\n'

# %%
num1 = int(input("첫 번째 수: "))
# Out:
# 첫 번째 수: 15

# %%
num2 = int(input("두 번째 수: "))
# Out:
# 두 번째 수: 10

# %%
num1/num2
# Out:
# 1.5

# %%
num1//num2
# Out:
# 1

# %%
num1%num2
# Out:
# 5

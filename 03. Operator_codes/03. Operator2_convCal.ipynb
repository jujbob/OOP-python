# %% [markdown]
# # Operator 활용 실습 #
#  - 개요: 편의점 총 매출액을 구하는 프로그램
#  - 입력: 매입한 물품, 판매한 물품
#  - 출력: 총 매출액
#  - 조건:
#
#  ![image.png](data:image/png;base64,...)

# %%
total = 0

# %%
total -= 900*10

# %%
total
# Out:
# -9000

# %%
total -= 3500*5

# %%
total
# Out:
# -26500

# %%
total += 1800*2
total += 4000*4
total += 1500*1
total += 2000*4
total += 1800*5

# %%
total
# Out:
# 11600

# %%
#인건비를 계산안함
total -= 9500 * 5

# %%
total
# Out:
# -35900

# %% [markdown]
# # String 활용 실습 #
#  - 개요: String 내장함수 활용코드

# %%
"123"
# Out:
# '123'

# %%
type("123")
# Out:
# str

# %%
type(123)
# Out:
# int

# %%
type('123')
# Out:
# str

# %%
""" My Name is 김가렌 """
# Out:
# ' My Name is 김가렌 '

# %%
"she's my lover"
# Out:
# "she's my lover"

# %%
'she\'s my lover'
# Out:
# "she's my lover"

# %%
print("she's my lover", end=' ')
print("I will save her for all my heart")
# Out:
# she's my lover I will save her for all my heart

# %%
text = """she's my lover. 
I will save her for all my heart"""

# %%
print(text)
# Out:
# she's my lover.
# I will save her for all my heart

# %%
"My name is " + str(5)
# Out:
# 'My name is 5'

# %%
type("5")
# Out:
# str

# %%
type(int("5"))
# Out:
# int

# %%
text = """she's my lover. I will save her for all my heart"""

# %%
print(text)
# Out:
# she's my lover. I will save her for all my heart

# %%
len(text)
# Out:
# 48

# %%
text = "내가 최고가 되겠어"

# %%
len(text)
# Out:
# 10

# %%
#0~9 indexes
text[0]
# Out:
# '내'

# %%
print(text[0],text[1],text[2],text[3],"저",text[5],text[6],text[7],text[8],text[9])
# Out:
# 내 가   최 저 가   되 겠 어

# %%
a = text[0:4]

# %%
c = text[5:10]

# %%
print(a+"고"+c)
# Out:
# 내가 최고가 되겠어

# %%
text[:-3]
# Out:
# '내가 최고가 '

# %%
text[:7]
# Out:
# '내가 최고가 '

# %%
input = "20010331Rainy"
output = "2001년 03월 31일 날씨:Rainy"

# %%
year = input[0:4]
month = input[4:6]
day = input[6:8]
wd = input[8:]

# %%
month
# Out:
# '03'

# %%
day
# Out:
# '31'

# %%
wd
# Out:
# 'Rainy'

# %%
print(year+"년", month+"월", day+"일", "날씨:",wd)
# Out:
# 2001년 03월 31일 날씨: Rainy

# %%
number = 3
"I eat %d apples." %number
# Out:
# 'I eat 3 apples.'

# %%
texxt = "five"
"I eat %s apples." %texxt
# Out:
# 'I eat five apples.'

# %%
number = 3
texxt = "five"
"I ate %d apples and %s vananas" %(number, texxt)
# Out:
# 'I ate 3 apples and five vananas'

# %%
"I ate "+ str(number) + " apples and "+ texxt +" vananas"
# Out:
# 'I ate 3 apples and five vananas'

# %%
"I got 4.5 score of Python"
# Out:
# 'I got 4.5 score of Python'

# %%
"I got %0.4f score of Python" %4.5
# Out:
# 'I got 4.5000 score of Python'

# %%
"I got {0} score of Python".format("four point five")
# Out:
# 'I got four point five score of Python'

# %%
textt = "I got {number}, {grade} score of Python"
print(textt)
texttt2 = textt.format(number="4.5", grade="A")
#print(textt)
# Out:
# I got {number}, {grade} score of Python

# %%
texttt2
# Out:
# 'I got 4.5, A score of Python'

# %%
#From Python 3.6

# %%
name = "김가렌"
age = int("24")
print(f'내이름은 {name}이라고해. 나는 데마시아의 수호자이고 나이는 {age+1}이야.')
# Out:
# 내이름은 김가렌이라고해. 나는 데마시아의 수호자이고 나이는 25이야.

# %%
a = "김티모 출동 준비중. 하나 둘 셋 넷"
a[a.find("출동")]
# Out:
# '출'

# %%
a = "life is too short and your life is also short and watch out your life"

# %%
a.replace("life", "my life")
# Out:
# 'my life is too short and your my life is also short. watch out your my life'

# %%
a.split(sep="and")
# Out:
# ['life is too short ', ' your life is also short ', ' watch out your life']

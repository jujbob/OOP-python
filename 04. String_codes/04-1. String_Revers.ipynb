# %% [markdown]
# # String 활용 실습 #
#  - 개요: 트와이스 글자 뒤집어 출력하기
#  - 입력: "트와이스"
#  - 출력: "스이와트"
#  - 조건: 스트링 내장함수 사용

# %%
ss = "트와이스"

# %%
ss
# Out:
# '트와이스'

# %%
ss[0]
# Out:
# '트'

# %%
ss[1]
# Out:
# '와'

# %%
ss[2]
# Out:
# '이'

# %%
ss[3]
# Out:
# '스'

# %%
print(ss[3]+ss[2]+ss[1]+ss[0])
# Out:
# 스이와트

# %%
print(ss[3], end='')
print(ss[2], end='')
print(ss[1], end='')
print(ss[0], end='')
# Out:
# 스이와트

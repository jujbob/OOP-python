# %% [markdown]
# # String 활용 실습 #
#  - 개요: Python 문자열 대문자는 소문자로 소문자는 대문자로 변경하기
#  - 입력: "Python"
#  - 출력: "pYTHON"
#  - 조건: 스트링 내장함수 사용

# %%
ss = "Python"

# %%
ss[0]
# Out:
# 'P'

# %%
ss[0].lower()
# Out:
# 'p'

# %%
print(ss[0].lower() +ss[1].upper() +ss[2].upper() +ss[3].upper() +ss[4].upper() +ss[5].upper())
# Out:
# pYTHON

# %%
len(ss)
# Out:
# 6

# %%
print(ss[0].islower())
# Out:
# False

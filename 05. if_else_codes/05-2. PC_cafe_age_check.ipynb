# %% [markdown]
# # 05. 조건문 실습
#  - 피시방에서 미성년자인지 확인하는 프로그램
#   *  입력: 로그인하려는 사용자의 나이
#   *  출력: 성인인지 아닌지 판단하여 출력
#   *  조건: 성인==만18세 이상

# %%
age = int(input("나이를 입력하세요"))
# Out:
# 나이를 입력하세요27

# %%
if age >= 18:
  print("성인님 즐거운 게임 하세요.")
else:
  print("미성년자는 밤 10시이후 사용이 불가합니다.")

print("정직하게 응답해주셔서 감사합니다.")
# Out:
# 성인님 즐거운 게임 하세요.
# 정직하게 응답해주셔서 감사합니다.

# %% [markdown]
# # 05. 조건문 실습
#  - 가위바위보 게임을 한다.
#   *  입력: 사용자의 가위/바위/보 선택
#   *  출력: 게임에서 이겼는지 졌는지 비겼는지 출력
#   *  조건: 가위는 바위에 진다... ~

# %%
import random

# %%
myNumber = random.randint(1,45)

# %%
myNumber
# Out:
# 35

# %%
game_selection_list = ['가위', '바위', '보']
# pick a random choice from a list of strings.
comHand = random.choice(game_selection_list)

# %%
myHand = input("가위바위보중에 골라주세요")
# Out:
# 가위바위보중에 골라주세요보재기

# %%
print(myHand, comHand)
# Out:
# 보재기 보

# %%
if myHand == "가위":
  if comHand == "가위":
    print("비겼다")
  elif comHand == "바위":
    print("졌다")
  elif comHand == "보":
    print("이겼다")
  ####
  ###
  ####
    print(ran_num, "개를 땄습니다.")

elif myHand == "바위":
  if comHand == "가위":
    print("이겼다")
  elif comHand == "바위":
    print("비겼다")
  elif comHand == "보":
    print("졌다")

elif myHand == "보":
  if comHand == "가위":
    print("졌다")
  elif comHand == "바위":
    print("이겼다")
  elif comHand == "보":
    print("비겼다")

else:
  print("가위/바위/보 중에 골라주세요")
# Out:
# 가위/바위/보 중에 골라주세요

# %% [markdown]
# ## 1. 일반적인 절차 지향적 프로그래밍

# %%
print("A님. 두 숫자 입력하세요")
num1 = int(input("정수1 ==>"))
num2 = int(input("정수2 ==>"))
hap = num1 + num2
print("결과 :", hap)

print("B님. 두 숫자 입력하세요")
num1 = int(input("정수1 ==>"))
num2 = int(input("정수2 ==>"))
hap = num1 + num2
print("결과 :", hap)

print("C님. 두 숫자 입력하세요")
num1 = int(input("정수1 ==>"))
num2 = int(input("정수2 ==>"))
hap = num1 + num2
print("결과 :", hap)
# Out:
# A님. 두 숫자 입력하세요
# 정수1 ==>5
# 정수2 ==>10
# 결과 : 15
# B님. 두 숫자 입력하세요
# 정수1 ==>15
# 정수2 ==>10
# 결과 : 25
# C님. 두 숫자 입력하세요
# 정수1 ==>1
# 정수2 ==>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e81b1c7fdce9> in <module>()
#      13 print("C님. 두 숫자 입력하세요")
#      14 num1 = int(input("정수1 ==>"))
# ---> 15 num2 = int(input("정수2 ==>"))
#      16 hap = num1 + num2
#      17 print("결과 :", hap)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def plus(num1, num2, num3=0):
  hap = num1 + num2 + num3
  print("plus결과 :", hap)
  return hap

# %%
for idx in range(2):
  print(idx, "님 더할 숫자를 입력하세요")
  #val1 = int(input("정수1 ==>"))
  #val2 = int(input("정수2 ==>"))
  val1 = idx+idx**2
  val2 = idx
  val3 = idx**2
  result_numtwo = plus(val1, val2)
  result_numthree = plus(val1, val2, val3)
# Out:
# 0 님 더할 숫자를 입력하세요
# plus결과 : 0
# plus결과 : 0
# 1 님 더할 숫자를 입력하세요
# plus결과 : 3
# plus결과 : 4

# %% [markdown]
# ## 3. 지역변수 전역변수

# %%
def para_func(v1, v2, v3=0) :
    result = 0
    result = v1 + v2 + v3
    return result

# %%
hap = 0

# %%
hap = para_func(10,20)

# %%
print("매개변수의 2개합의 결과", hap)
# Out:
# 매개변수의 2개합의 결과 30

# %%
hap = para_func(10,20,30)

# %%
print("매개변수의 3개합의 결과", hap)
# Out:
# 매개변수의 3개합의 결과 60

# %%
def para_func2(v1, v2, v3=0) :
    result = 0
    result = v1 + v2 + v3 + hap
    print(result)
    hap = result
    return result

# %%
para_func2(10,0,0)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-50-5f48e9cff604> in <module>()
# ----> 1 para_func2(10,0,0)
#
# <ipython-input-49-94b963c56cdd> in para_func2(v1, v2, v3)
#       1 def para_func2(v1, v2, v3=0) :
#       2     result = 0
# ----> 3     result = v1 + v2 + v3 + hap
#       4     print(result)
#       5     hap = result
#
# UnboundLocalError: local variable 'hap' referenced before assignment

# %%
hap
# Out:
# 70

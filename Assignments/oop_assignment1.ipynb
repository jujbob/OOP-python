# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import random

# %% [markdown]
# ## 1.
#
# ![image.png](data:image/png;base64,...)
#
# (https://www.acmicpc.net/problem/9498)

# %% [markdown]
# ## 1.1 if-else 문을 통해 해결

# %%
## 1.1
# 코드 작성 부분

# %% [markdown]
# ## 1.2 match-case문을 통해 해결
#
# match-case 문: **python 3.10부터 지원**
#
# [참고](https://www.geeksforgeeks.org/python-match-case-statement/)
#
# ```python
# match expression:
#     case pattern1:
#         # code block for pattern1
#     case pattern2:
#         # code block for pattern2
#     ...
#     case patternN:
#         # code block for patternN
#     case _:
#         # default code block
# ```

# %%
## 1.2
# 코드 작성 부분

# %% [markdown]
# # Conditional expression
#
# ```python
# if x >= 0:
#     sign = "+"
# else:
#     sign = "-"
# ```
#
# 위의 코드를 conditional expression을 통해 나타내면
#
# ```python
# sign = "+" if x >= 0 else "-"
# ```
#
# 으로 나타낼 수 있다.
#
# **아래 `if-else`로 주어지는 코드를 conditional expression으로 변경하세요.**

# %% [markdown]
# ## 2.
# [0, 100] 범위에서 정수 $x$를 random select한 뒤, $x$가 짝수면 `{x} is even.` 출력, 홀수면 `{x} is odd.` 출력.

# %%
### if-else

x = random.randint(0, 100)

if x%2 == 0:
    print(f"{x} is even.")
else:
    print(f"{x} is odd.")


### conditional expression
# 코드 작성 부분
# Out:
# 52 is even.

# %% [markdown]
# ## 3.
# [0, 100] 범위에서 두 수 a, b를 random select한 뒤, a와 b가 서로소이면 최대공약수 출력, 서로소가 아니면 최소공배수 출력.

# %%
### if-else
a = random.randint(0, 100)
b = random.randint(0, 100)
# 코드 작성 부분





### conditional expression
# 코드 작성 부분

# %% [markdown]
# ## 4.
#
# 팰린드롬은 거꾸로 읽어도 똑같은 문자열이나 숫자를 말한다.
#
# (기러기, 토마토, 별똥별, 우영우, 1234321, 등)
#
# 문자열 x가 주어졌을 때, 해당 문자열이 팰린드롬이면 `is_palindrome` 변수에 `True`를, 아니면 `False`를 할당하는 코드를 작성하세요.
#
# > _**힌트** 문자열 or list 역순으로 배치하는 방법 찾아보기_

# %%
x = "가나다라마라다나가"

is_palindrome = None

# %% [markdown]
# # for loop

# %% [markdown]
# ## 5.
#
# 1부터 1000까지의 숫자 중에서 특정 조건을 만족하는 숫자들의 합 구하기.
#
# 조건:
# 1. 해당 숫자가 3의 배수이거나 5의 배수
# 2. 해당 숫자의 모든 자릿수의 합이 10이상

# %%
# 코드 작성 부분

# %% [markdown]
# ## 6.
#
# 높이를 입력받아 별(*) 피라미드 출력.
#
# 조건:
# 1. 피라미드의 높이는 사용자 입력으로 결정
# 2. 각 줄은 중앙을 기준으로 정렬되어야 함
#
#
#
# ex. 높이 = 5
# ```python
#     *
#    ***
#   *****
#  *******
# *********
# ```

# %%
### 코드 작성 부분
# Out:
# True

# %% [markdown]
# ## 7.
#
# 두 정수 $x \in \{0, 1, 2, ..., 10\}, \;$
# $y \in \{-5, -4, -3, ..., 4, 5\}$ 에 대하여, 모든 $(x, y)$를 순회하며 $x^2 y$를 출력.
#
# 단, 가로축이 x, 세로축이 y가 되도록 출력
#
# 출력 예시
#
# ![image.png](data:image/png;base64,...)
#
# 힌트 : `print(..., end="\t")`

# %%
# 코드 작성 부분

# %% [markdown]
# ## 8.
#
# 두 벡터 $\mathbf{a}, \mathbf{b}$의 내적은 다음과 같이 계산된다.
# $$
# \langle a, b ⟩ = \sum_{i} a_ib_i
# $$
#
# 벡터 $\mathbf{a} = [-10, -9, \cdots, 18, 19, 20], \mathbf{b} = [30, 29, \cdots, 2, 1, 0]$ 일 때, 두 벡터의 내적을 구하는 코드를 작성

# %%
# 코드 작성 부분

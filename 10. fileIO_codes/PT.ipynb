# %%
inFile = None
inStr = ""

inFile = open('./myData1.txt')

# %%
inStr = inFile.readline()
inStr
# Out:
# '코딩이 재미있어 졌어요\n'

# %%
inStr = inFile.readline()
inStr
# Out:
# '이젠 코딩 전문가 된 것 같아요. ^^'

# %%
inStr = inFile.readline()
inStr
# Out:
# ''

# %%
inFile.close()

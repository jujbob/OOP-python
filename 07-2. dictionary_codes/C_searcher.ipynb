# %% [markdown]
# # 편의점의 재고를 관리하는 프로그램을 작성하시오
#  - 문제의 정의: 편의점에 들어올 물품의 물품명과 갯수를 저장하는 딕셔너리를 만들고 물품명을 입력받아 그 제고 수를 출력하는 프로그램을 만드시오
#  - 입력: 물품명, 수량, 검색하고싶은 물품명
#  - 출력: 물품의 갯수

# %%
obj_dict = {}

while True:
  obj = input("입고된 물품을 입력하세요")
  if obj == 'n':
    break
  count = input("입고된 물품의 수량을 입력하세요")
  obj_dict[obj] = count


while True:
  obj_search = input("검색하고자 하는 물품명 입력하세요")
  if obj_search == "":
    break
  print("물건의 갯수는 ",obj_dict[obj_search], "입니다")
  obj_ch = input("수량을 몇개로 변경하시겠습니까")
  #######
# Out:
# 입고된 물품을 입력하세요삼각김밥
# 입고된 물품의 수량을 입력하세요10
# 입고된 물품을 입력하세요바나나우유
# 입고된 물품의 수량을 입력하세요5
# 입고된 물품을 입력하세요교촌치킨
# 입고된 물품의 수량을 입력하세요30
# 입고된 물품을 입력하세요한우 4근
# 입고된 물품의 수량을 입력하세요1
# 입고된 물품을 입력하세요n
# 검색하고자 하는 물품명 입력하세요한우 4근
# 1
# 검색하고자 하는 물품명 입력하세요삼각김밥
# 10
# 검색하고자 하는 물품명 입력하세요교촌치킨
# 30
# 검색하고자 하는 물품명 입력하세요

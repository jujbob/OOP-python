# %% [markdown]
# # Variable 기초 예제 #
#  - 주제: input function을 이용해서 자기소개 하기
#  - 방법: 사용자로부터 변수 두 개를 입력으로 받아 자기 이름과 연락처를 출력하는 프로그램을 작성하세요.

# %%
userName = input("이름 ==>")
# Out:
# 이름 ==>김가렌

# %%
userName
# Out:
# '김가렌'

# %%
userPhone = input("전화번호 ==>")
# Out:
# 전화번호 ==>010112114

# %%
userPhone
# Out:
# '010112114'

# %%
print("제이름은", userName, "전화번호는", userPhone, "입니다.")
# Out:
# 제이름은 김가렌 전화번호는 010112114 입니다.

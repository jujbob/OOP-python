# %% [markdown]
# # 숫자형 데이터 기초 예제 #
#  - 숫자형 데이터의 정의: 숫자형태로 이루어진 자료
#  - 숫자형 데이터의 종류: 정수, 실수, 진수

# %%
1234
# Out:
# 1234

# %%
-1234
# Out:
# -1234

# %%
0
# Out:
# 0

# %%
12.34
# Out:
# 12.34

# %%
pi = 3.1415

# %%
pi
# Out:
# 3.1415

# %%
type(pi)
# Out:
# float

# %%
type(3)
# Out:
# int

# %%
type(int(pi))
# Out:
# int

# %%
type("헬로 파이썬")
# Out:
# str

# %%
a = 3
b = 4

# %%
a ** b
# Out:
# 81

# %%
#3^4
3*3*3*3
#asdfasdfsa
#fasdfasdf
#asdf
#
# Out:
# 81

# %%
7 // 4
# Out:
# 1

# %%
7/4
# Out:
# 1.75
